# %%
# %matplotlib inline
from numpy import *
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pandas
import seaborn
from scipy import stats
BASE_DIR = '.'
dataset = pandas.read_csv(BASE_DIR + "/input/wtageinf.csv")
dataset.head(10)
#dataset.shape
# Out:
#    Sex  Agemos         L         M         S        P3        P5       P10  \
# 0    1     0.0  1.815151  3.530203  0.152385  2.355451  2.526904  2.773802
# 1    1     0.5  1.547523  4.003106  0.146025  2.799549  2.964656  3.209510
# 2    1     1.5  1.068796  4.879525  0.136479  3.614688  3.774849  4.020561
# 3    1     2.5  0.695974  5.672889  0.129678  4.342341  4.503255  4.754479
# 4    1     3.5  0.419815  6.391392  0.124717  4.992898  5.157412  5.416803
# 5    1     4.5  0.219867  7.041836  0.121040  5.575169  5.744752  6.013716
# 6    1     5.5  0.077506  7.630425  0.118271  6.096775  6.272175  6.551379
# 7    1     6.5 -0.021908  8.162951  0.116154  6.564430  6.745993  7.035656
# 8    1     7.5 -0.089441  8.644832  0.114510  6.984123  7.171952  7.472021
# 9    1     8.5 -0.133409  9.081120  0.113217  7.361236  7.555287  7.865533
#
#         P25       P50       P75        P90        P95        P97
# 0  3.150611  3.530203  3.879077   4.172493   4.340293   4.446488
# ...

# %%
sexo = 1
sexoFilter = dataset["Sex"] == sexo
dataset_varon = dataset[sexoFilter]

sexo = 2
sexoFilter = dataset["Sex"] == sexo
dataset_mujer = dataset[sexoFilter]

agemosVaron = dataset_varon['Agemos'].dropna()
agemosMujer = dataset_mujer['Agemos'].dropna()

p3Hombre = dataset_varon['P3'].dropna()
p5Hombre = dataset_varon['P5'].dropna()
p10Hombre = dataset_varon['P10'].dropna()
p25Hombre = dataset_varon['P25'].dropna()
p50Hombre = dataset_varon['P50'].dropna()
p75Hombre = dataset_varon['P75'].dropna()
p90Hombre = dataset_varon['P90'].dropna()
p95Hombre = dataset_varon['P95'].dropna()
p97Hombre = dataset_varon['P97'].dropna()

p3Mujer = dataset_mujer['P3'].dropna()
p5Mujer = dataset_mujer['P5'].dropna()
p10Mujer = dataset_mujer['P10'].dropna()
p25Mujer = dataset_mujer['P25'].dropna()
p50Mujer = dataset_mujer['P50'].dropna()
p75Mujer = dataset_mujer['P75'].dropna()
p90Mujer = dataset_mujer['P90'].dropna()
p95Mujer = dataset_mujer['P95'].dropna()
p97Mujer = dataset_mujer['P97'].dropna()


# Plot with differently-colored markers.
plt.plot(agemosMujer, p3Mujer, 'b', label='P3 - Mujer')
plt.plot(agemosMujer, p5Mujer, 'y-', label='P3 - Mujer')
plt.plot(agemosMujer, p10Mujer,'k-', label='P3 - Mujer')
plt.plot(agemosMujer, p25Mujer, 'w-', label='P3 - Mujer')
plt.plot(agemosMujer, p50Mujer, 'c-', label='P3 - Mujer')
plt.plot(agemosMujer, p75Mujer, 'm-', label='P3 - Mujer')
plt.plot(agemosMujer, p90Mujer, 'w-', label='P3 - Mujer')
plt.plot(agemosMujer, p95Mujer, 'r-', label='P3 - Mujer')
plt.plot(agemosMujer, p97Mujer, 'b', label='P3 - Mujer')

# %%
plt.plot(agemosVaron, p3Hombre, 'g-', label='P3 - Hombre')
plt.xlabel("agemos")
plt.ylabel("Percentiles")
plt.legend()
plt.show()

# %%
plt.plot(agemosVaron, p3Hombre, 'b', label='P3 - Hombre')
plt.plot(agemosVaron, p5Hombre, 'g', label='P5 - Hombre')
plt.plot(agemosVaron, p10Hombre,'c', label='P10 - Hombre')
plt.plot(agemosVaron, p25Hombre, 'd', label='P3 - Hombre')
plt.plot(agemosVaron, p50Hombre, 'y', label='P3 - Hombre')
